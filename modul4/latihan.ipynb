# %% [markdown]
# ### Latihan 1

# %%
def is_positive():
    return n > 0

# %%
check_number1 = is_positive
check_number2 = is_positive(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 check_number1 = is_positive
# ----> 2 check_number2 = is_positive(1)
#
# TypeError: is_positive() takes 0 positional arguments but 1 was given

# %% [markdown]
# ### Latihan 2

# %%
data = filter(lambda x: x % 2, range(10))
hasil = map(lambda x: str(x * 10) + '%', data)

# %% [markdown]
# ### Latihan 3
